# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Pivot tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    809     98   John  January      Q1
# 1  2023-01-02       B   West    359     66   Mary  January      Q1
# 2  2023-01-03       C  North    379     22    Bob  January      Q1
# 3  2023-01-04       D  South    528     20  Alice  January      Q1
# 4  2023-01-05       A   East    860     92   John  January      Q1
# 5  2023-01-06       B   West    335     31   Mary  January      Q1
# 6  2023-01-07       C  North    620     40    Bob  January      Q1
# 7  2023-01-08       D  South    909     85  Alice  January      Q1
# 8  2023-01-09       A   East    585     57   John  January      Q1
# 9  2023-01-10       B   West    681     14   Mary  January      Q1
# 10 2023-01-11       C  North    296     94    Bob  January      Q1
# 11 2023-01-12       D  South    685     30  Alice  January      Q1
# 12 2023-01-13       A   East    199     54   John  January      Q1
# 13 2023-01-14       B   West    972     58   Mary  January      Q1
# 14 2023-01-15       C  North    553     47    Bob  January      Q1
# 15 2023-01-16       D  South    649     50  Alice  January      Q1
# 16 2023-01-17       A   East    747     98   John  January      Q1
# 17 2023-01-18       B   West    682     36   Mary  January      Q1
# 18 2023-01-19       C  North    803     45    Bob  January      Q1
# 19 2023-01-20       D  South    943     84  Alice  January      Q1

# %%
pd.pivot_table(df, values="Sales",index="Region", columns="Product",aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     747.0    NaN    NaN    NaN
# North      NaN    NaN  553.0    NaN
# South      NaN    NaN    NaN  685.0
# West       NaN  681.0    NaN    NaN

# %%
pivot2=pd.pivot_table(df, values=["Sales","Units"],index="Region", columns="Product")
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     640.0    NaN    NaN    NaN  79.8   NaN   NaN   NaN
# North      NaN    NaN  530.2    NaN   NaN   NaN  49.6   NaN
# South      NaN    NaN    NaN  742.8   NaN   NaN   NaN  53.8
# West       NaN  605.8    NaN    NaN   NaN  41.0   NaN   NaN

# %% [markdown]
# # Cross tabs

# %%
pd.crosstab(df["Region"],df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
